# %% [markdown]
# <span style='color:#008000; font-size:20pt; font-weight:bold'>Import Libraries</span>

# %%
import pandas as pd
import re

pd.set_option('display.max_rows', None) # This code will display all of the dataframe
# pd.reset_option('all') # Reset to default

# %% [markdown]
# <span style='color:#008000; font-size:20pt; font-weight:bold'>Loading Dataset</span>

# %%
movielens_movies = pd.read_csv('movielens-1m/movies.dat', sep='::', engine='python', 
                        names=['movieId', 'title', 'genres'], encoding='ISO-8859-1')

# %%
movie_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)

# %% [markdown]
# <span style='color:#008000; font-size:20pt; font-weight:bold'>Data Cleaning</span>

# %% [markdown]
# <span style='color:#007ACC; font-size:15pt; font-weight:bold'>MovieLens-1M</span>

# %%
movielens_movies.tail()
# Out:
#       movieId                       title          genres
# 3878     3948     Meet the Parents (2000)          Comedy
# 3879     3949  Requiem for a Dream (2000)           Drama
# 3880     3950            Tigerland (2000)           Drama
# 3881     3951     Two Family House (2000)           Drama
# 3882     3952       Contender, The (2000)  Drama|Thriller

# %%
# Extracts the year from the movie title using regex pattern that looks for four-digit numbers within parentheses.
movielens_movies['year'] = movielens_movies['title'].str.extract(r'\((\d{4})\)')

# Removes the extracted year (four-digit numbers in parentheses) from the title, 
# ensuring only the movie name remains, and strips any extra spaces.
movielens_movies['title'] = movielens_movies['title'].str.replace(r'\(\d{4}\)', '', regex=True).str.strip()

# Replaces multiple spaces in the movie title with a single space to ensure a clean format.
movielens_movies['title'] = movielens_movies['title'].str.replace(r'\s+', ' ', regex=True).str.strip()

# Title got error E.g: "Contender, The"
# Fix titles by using regex
def fix_title_regex(title):
    return re.sub(r"^(.*), (The|A|An|L'|Le)( \(.+\))?$", r'\2 \1\3', title)
movielens_movies['title'] = movielens_movies['title'].apply(fix_title_regex)

# %%
movielens_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3883 entries, 0 to 3882
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  3883 non-null   int64
#  1   title    3883 non-null   object
#  2   genres   3883 non-null   object
#  3   year     3883 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 121.5+ KB

# %% [markdown]
# <span style='color:#007ACC; font-size:15pt; font-weight:bold'>Movie-Metadata</span>

# %%
movie_metadata['release_date'] = movie_metadata['release_date'].astype(str).str[:4]         
movie_metadata['title'] = movie_metadata['title'].str.replace(r'\s+', ' ', regex=True).str.strip()

# %% [markdown]
# <span style='color:#007ACC; font-size:15pt; font-weight:bold'>Merging btw MovieLens_Movies and Movie_Metadata</span>

# %%
merged = pd.merge(movielens_movies, movie_metadata[['title', 'release_date', 'overview']], 
                    left_on=['title', 'year'], right_on=['title', 'release_date'], how='left')

# %%
merged.head(5)
# Out:
#    movieId                        title                        genres  year  \
# 0        1                    Toy Story   Animation|Children's|Comedy  1995
# 1        2                      Jumanji  Adventure|Children's|Fantasy  1995
# 2        3             Grumpier Old Men                Comedy|Romance  1995
# 3        4            Waiting to Exhale                  Comedy|Drama  1995
# 4        5  Father of the Bride Part II                        Comedy  1995
#
#   release_date                                           overview
# 0         1995  Led by Woody, Andy's toys live happily in his ...
# 1         1995  When siblings Judy and Peter discover an encha...
# 2         1995  A family wedding reignites the ancient feud be...
# 3         1995  Cheated on, mistreated and stepped on, the wom...
# 4         1995  Just when George Banks has recovered from his ...

# %%
merged.isna().sum()
# Out:
# movieId           0
# title             0
# genres            0
# year              0
# release_date    853
# overview        861
# dtype: int64

# %%
merged = merged.drop_duplicates(subset=['movieId', 'title', 'year'])

# %%
merged = merged.rename(columns={'overview':'description'})

# %%
merged = merged[['movieId', 'title', 'genres', 'year', 'description']]
merged
# Out:
#       movieId                                              title  \
# 0           1                                          Toy Story
# 1           2                                            Jumanji
# 2           3                                   Grumpier Old Men
# 3           4                                  Waiting to Exhale
# 4           5                        Father of the Bride Part II
# 5           6                                               Heat
# 6           7                                            Sabrina
# 7           8                                       Tom and Huck
# 8           9                                       Sudden Death
# 9          10                                          GoldenEye
# 10         11                             The American President
# 11         12                        Dracula: Dead and Loving It
# 12         13                                              Balto
# 13         14                                              Nixon
# 14         15                                   Cutthroat Island
# 15         16                                             Casino
# 16         17                              Sense and Sensibility
# 17         18                                         Four Rooms
# 18         19                     Ace Ventura: When Nature Calls
# 19         20                                        Money Train
# 20         21                                         Get Shorty
# 21         22                                            Copycat
# 22         23                                          Assassins
# 23         24                                             Powder
# 24         25                                  Leaving Las Vegas
# 25         26                                            Othello
# 26         27                                       Now and Then
# 27         28                                         Persuasion
# 28         29                          The City of Lost Children
# 29         30      Shanghai Triad (Yao a yao yao dao waipo qiao)
# 30         31                                    Dangerous Minds
# 31         32                                     Twelve Monkeys
# 32         33                                   Wings of Courage
# 33         34                                               Babe
# 34         35                                         Carrington
# 35         36                                   Dead Man Walking
# 36         37                             Across the Sea of Time
# 37         38                                       It Takes Two
# 38         39                                           Clueless
# 39         40                           Cry, the Beloved Country
# 40         41                                        Richard III
# 41         42                                    Dead Presidents
# 42         43                                        Restoration
# 43         44                                      Mortal Kombat
# 44         45                                         To Die For
# 45         46                      How to Make an American Quilt
# 46         47                                      Seven (Se7en)
# 47         48                                         Pocahontas
# 48         49                              When Night Is Falling
# 49         50                                 The Usual Suspects
# 50         51                                     Guardian Angel
# 51         52                                   Mighty Aphrodite
# 52         53                                           Lamerica
# 53         54                                      The Big Green
# 54         55                                            Georgia
# 55         56                            Kids of the Round Table
# 56         57                              Home for the Holidays
# 57         58                          Postino, Il (The Postman)
# 58         59                The Confessional (Le Confessionnal)
# 59         60                         The Indian in the Cupboard
# 60         61                                     Eye for an Eye
# 61         62                                 Mr. Holland's Opus
# 62         63  Don't Be a Menace to South Central While Drink...
# 63         64                                      Two if by Sea
# 64         65                                           Bio-Dome
# 65         66                 Lawnmower Man 2: Beyond Cyberspace
# 66         67                                           Two Bits
# 67         68                        French Twist (Gazon maudit)
# 68         69                                             Friday
# 69         70                                From Dusk Till Dawn
# 70         71                                          Fair Game
# 71         72                              Kicking and Screaming
# 72         73                                    Misérables, Les
# 73         74                                       Bed of Roses
# 74         75                                          Big Bully
# 75         76                                          Screamers
# 76         77                                          Nico Icon
# 77         78                                 The Crossing Guard
# 78         79                                          The Juror
# 79         80               The White Balloon (Badkonake Sefid )
# 80         81            Things to Do in Denver when You're Dead
# 266       269                       My Crazy Life (Mi vida loca)
# 267       270                                        Love Affair
# 268       271                                      Losing Isaiah
# 269       272                         The Madness of King George
# 270       273                        Mary Shelley's Frankenstein
# 271       274                                   Man of the House
# 272       275                                         Mixed Nuts
# 273       276                                         Milk Money
# 274       277                             Miracle on 34th Street
# 275       278                                     Miami Rhapsody
# 276       279                                          My Family
# 277       280                                Murder in the First
# 278       281                                      Nobody's Fool
# 279       282                                               Nell
# 280       283                                   New Jersey Drive
# 281       284                                       New York Cop
# 282       285                                      Beyond Bedlam
# 283       286                                  Nemesis 2: Nebula
# 284       287                                 Nina Takes a Lover
# 285       288                               Natural Born Killers
# 286       289                                           Only You
# 287       290                                 Once Were Warriors
# 288       291                                      Poison Ivy II
# 289       292                                           Outbreak
# 290       293   The Professional (a.k.a. Leon: The Professional)
# 291       294                                   The Perez Family
# 292       295                          A Pyromaniac's Love Story
# 293       296                                       Pulp Fiction
# 294       297                                            Panther
# 295       298                                      Pushing Hands
# 296       299                                             Priest
# 297       300                                          Quiz Show
# 298       301                                      Picture Bride
# 299       302                     Queen Margot (La Reine Margot)
# 300       303                             The Quick and the Dead
# 301       304                                          Roommates
# 302       305                      Ready to Wear (Pret-A-Porter)
# 303       306                                  Three Colors: Red
# 304       307                                 Three Colors: Blue
# 305       308                                Three Colors: White
# 306       309                 Red Firecracker, Green Firecracker
# 307       310                                         Rent-a-Kid
# 308       311                                      Relative Fear
# 309       312                            Stuart Saves His Family
# 310       313                                  The Swan Princess
# 311       314                           The Secret of Roan Inish
# 312       315                                     The Specialist
# 313       316                                           Stargate
# 314       317                                   The Santa Clause
# 315       318                           The Shawshank Redemption
# 316       319                                      Shallow Grave
# 317       320                                             Suture
# 318       321       Strawberry and Chocolate (Fresa y chocolate)
# 319       322                               Swimming with Sharks
# 320       324                                      The Sum of Us
# 321       325                     National Lampoon's Senior Trip
# 322       326                                   To Live (Huozhe)
# 323       327                                          Tank Girl
# 324       328        Tales From the Crypt Presents: Demon Knight
# 325       329                             Star Trek: Generations
# 326       330                                Tales from the Hood
# 327       331                                          Tom & Viv
# 328       332                              Village of the Damned
# 329       333                                          Tommy Boy
# 330       334                               Vanya on 42nd Street
# 331       335                                     The Underneath
# 332       336                                   The Walking Dead
# 333       337                        What's Eating Gilbert Grape
# 334       338                                         Virtuosity
# 335       339                            While You Were Sleeping
# 336       340                                            The War
# 337       341                                   Double Happiness
# 338       342                                   Muriel's Wedding
# 339       343                              The Baby-Sitters Club
# 340       344                         Ace Ventura: Pet Detective
# 341       345   The Adventures of Priscilla, Queen of the Desert
# 342       346                                           Backbeat
# 343       347                                        Bitter Moon
# 344       348                              Bullets Over Broadway
# 345       349                           Clear and Present Danger
# 346       350                                         The Client
# 347       351                                   Corrina, Corrina
# 348       352                                           Crooklyn
# 349       353                                           The Crow
# 350       354                                               Cobb
# 351       355                                    The Flintstones
# 352       356                                       Forrest Gump
# 353       357                        Four Weddings and a Funeral
# 354       358                                    Higher Learning
# 355       359                                I Like It Like That
# 356       360                                     I Love Trouble
# 636       641  Little Indian, Big City (Un indien dans la ville)
# 637       642                                              Roula
# 638       643                     Peanuts - Die Bank zahlt alles
# 639       644                                      Happy Weekend
# 640       645                            Nelly & Monsieur Arnaud
# 641       647                                 Courage Under Fire
# 642       648                                Mission: Impossible
# 643       649                        Cold Fever (Á köldum klaka)
# 644       650                                      Moll Flanders
# 645       651                                     Superweib, Das
# 646       652                                           301, 302
# 647       653                                        Dragonheart
# 648       654                          Und keiner weint mir nach
# 649       655                                    Mutters Courage
# 650       656                                              Eddie
# 651       657                                        Yankee Zulu
# 652       658                                    Billy's Holiday
# 653       659                                        Purple Noon
# 654       660                                             August
# 655       661                          James and the Giant Peach
# 656       662                                               Fear
# 657       663                      Kids in the Hall: Brain Candy
# 658       664                                           Faithful
# 659       665                                        Underground
# 660       666                                    All Things Fair
# 661       667                                       Bloodsport 2
# 662       668                                    Pather Panchali
# 663       669                                          Aparajito
# 664       670                     The World of Apu (Apur Sansar)
# 665       671            Mystery Science Theater 3000: The Movie
# 666       672                                         Tarantella
# 667       673                                          Space Jam
# 668       674                                         Barbarella
# 669       675                                 Hostile Intentions
# 670       676                                          They Bite
# 671       678                   Some Folks Call It a Sling Blade
# 672       679                             The Run of the Country
# 673       680                                         Alphaville
# 674       681                      Clean Slate (Coup de Torchon)
# 675       682                Tigrero: A Film That Was Never Made
# 676       683               The Eye of Vichy (Oeil de Vichy, L')
# 677       684                                            Windows
# 678       685                                      It's My Party
# 679       687                                       Country Life
# 680       688                               Operation Dumbo Drop
# 681       690                     The Promise (Versprechen, Das)
# 682       691                                  Mrs. Winterbourne
# 683       692                                               Solo
# 684       693           Under the Domin Tree (Etz Hadomim Tafus)
# 685       694                                     The Substitute
# 686       695                                         True Crime
# 687       696                                     Butterfly Kiss
# 688       697                                  Feeling Minnesota
# 689       698                                     Delta of Venus
# 690       699                               To Cross the Rubicon
# 691       700                                              Angus
# 692       701                                              Daens
# 693       702                                              Faces
# 694       703                                               Boys
# 695       704                                          The Quest
# 696       705                                               Cosi
# 697       706                                        Sunset Park
# 698       707                                   Mulholland Falls
# 699       708                        The Truth About Cats & Dogs
# 700       709                                   Oliver & Company
# 701       710                                       Celtic Pride
# 702       711                                            Flipper
# 703       712                                           Captives
# ...
# 3614  This is a paralyzingly beautiful documentary w...
# 3615  Frankie is a heroin addict and sits in prison....
# 3616  The Los Angeles punk music scene circa 1980 is...
# 3617  An exploration of the heavy metal scene in Los...
# 3618  Two bounty hunters are in pursuit of "El Indio...
# 3619  "Dirty" Harry Calahan is a San Francisco Polic...
# 3620  The owner of a seedy small-town Texas bar disc...
# 3621  Frank and Jack Baker are professional musician...
# 3622  A professional hit man and hit woman fall in l...
# 3623  Five medical students want to find out if ther...
# 3624                                                NaN
# 3625  Set in 1954, a group of Florida high schoolers...
# 3626  When the students of Angel Beach High decide t...
# 3627                                                NaN
# 3628  Private-school student Christine loves Jim. Bu...
# 3629  The pupils at a high school next to a nuclear ...
# 3630                                                NaN
# 3631                                                NaN
# 3632  Toxie finds he has nothing to do as a superher...
# 3856                                                NaN
# 3857  Anthropology Professor Robert Orwell Sutwell a...
# 3858  A millionaire sets out to prove his theory tha...
# 3859  Fifteen years after his father's experiments w...
# 3860  A Martian teenager sent to prepare for an inva...
# 3861  Rootless Hungarian émigré Willie, his pal Eddi...
# 3862  The crew of an atomic submarine battle to save...
# 3863  The science of miniaturization has been unlock...
# 3864  Two hapless frieght handlers find themselves e...
# 3865  Egbert Sousé becomes an unexpected hero when a...
# 3866                                                NaN
# 3867  A small town in Texas finds itself under attac...
# 3868  Working in Dr. Cranley's laboratory, scientist...
# 3869  Trapped on a remote island by a hurricane, a g...
# 3870  Scientists investigate what appears to be a me...
# 3871                                                NaN
# 3872                                                NaN
# 3873  In the near future, a police officer specializ...
# 3874  An 18-year-old high school girl is left at hom...
# 3875                                                NaN
# 3876                                                NaN
# 3877  A little girl's brother kills the whole family...
# 3878  Five college women buy the old Hokstedter plac...
# 3879  TV producer Pierre Delacroix (Damon Wayans) be...
# 3880  Sean Odkin loves to dance much to his fathers ...
# 3881  The first story focused on Tai and Kari Kamiya...
# 3882  Remake of the Michael Caine classic. Jack Cart...
# 3883  Michael Caine is Jack Carter, a small-time hoo...
# 3884  Greg Focker is ready to marry his girlfriend, ...
# 3885  The hopes and dreams of four ambitious people ...
# 3886  A group of recruits go through Advanced Infant...
# 3887  Buddy Visalo (Michael Rispoli) is a factory wo...
# 3888  Political thriller about Laine Hanson's nomina...

# %%
merged.isna().sum()
# Out:
# movieId          0
# title            0
# genres           0
# year             0
# description    861
# dtype: int64

# %%
unmatched_titles = movielens_movies[~movielens_movies['title'].isin(movie_metadata['title'])]
unmatched_titles

# %%
merged[pd.isna(merged['description'])]

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3883 entries, 0 to 3888
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   movieId      3883 non-null   int64
#  1   title        3883 non-null   object
#  2   genres       3883 non-null   object
#  3   year         3883 non-null   object
#  4   description  3022 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 182.0+ KB

# %%
missing_descriptions = merged[pd.isna(merged['description'])]
print(f"Number of missing description movies: {len(missing_descriptions)}")
# Out:
# Number of missing description movies: 861

# %% [markdown]
# <span style='color:#007ACC; font-size:15pt; font-weight:bold'>Call OMDB API to fill in missing description movies</span>

# %%
import requests
import time

API_KEY = "271a55f8"

def fetch_movie_description(title):
    url = f"http://www.omdbapi.com/?t={title}&apikey={API_KEY}"
    response = requests.get(url)
    data = response.json()
    
    if "Plot" in data and data["Plot"] != "N/A":
        return data["Plot"]
    
    return "No description available"

# %%
merged['description'] = merged.apply(
    lambda row: fetch_movie_description(row['title']) if pd.isna(row['description']) else row['description'],
    axis=1
)

# %%
print(f"Number of missing description movies: {merged['description'].isna().sum()}")
# Out:
# Number of missing description movies: 0

# %% [markdown]
# <span style='color:#007ACC; font-size:15pt; font-weight:bold'>Extract to CSV file</span>

# %%
merged.to_csv('movielens_movies_with_descriptions.csv', index=False, encoding='utf-8')

# %% [markdown]
# # 📌 Bước 1: Đọc dữ liệu

# %%
import pandas as pd

# Đọc dữ liệu
ratings = pd.read_csv('/mnt/data/ratings.dat', sep='::', engine='python', names=['userId', 'movieId', 'rating', 'timestamp'], encoding='latin1')
movies = pd.read_csv('/mnt/data/movies.dat', sep='::', engine='python', names=['movieId', 'title', 'genres'], encoding='latin1')
users = pd.read_csv('/mnt/data/users.dat', sep='::', engine='python', names=['userId', 'gender', 'age', 'occupation', 'zip'], encoding='latin1')

# Hiển thị thông tin cơ bản
print(f"Số lượng user: {ratings['userId'].nunique()}")
print(f"Số lượng movie: {ratings['movieId'].nunique()}")
print(f"Số lượng rating: {len(ratings)}")

ratings.head()

# %% [markdown]
# # 📊 Bước 2: Thực hiện EDA

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Vẽ biểu đồ phân phối rating
plt.figure(figsize=(8,5))
sns.histplot(ratings['rating'], bins=np.arange(0.5, 5.5, 0.5), kde=True)
plt.xlabel('Rating')
plt.ylabel('Count')
plt.title('Phân phối Rating')
plt.grid(True)
plt.show()

# %%
# Phân tích thể loại phim (genres)
all_genres = movies['genres'].str.split('|').explode()
genre_counts = all_genres.value_counts()

# Vẽ biểu đồ thể loại phim
plt.figure(figsize=(12,6))
sns.barplot(x=genre_counts.index, y=genre_counts.values, palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Genres')
plt.ylabel('Số lượng phim')
plt.title('Tần suất thể loại phim')
plt.show()

# %%
# Top 10 phim được đánh giá nhiều nhất
top_n_movies = ratings['movieId'].value_counts().head(10)
top_movies = movies[movies['movieId'].isin(top_n_movies.index)]

print("Top 10 phim có nhiều rating nhất:")
top_movies.merge(top_n_movies, left_on="movieId", right_index=True).rename(columns={"movieId": "Movie ID", "title": "Title", "rating": "Number of Ratings"})

# %%
# Tính sparsity của ma trận user-item
num_users = ratings['userId'].nunique()
num_movies = ratings['movieId'].nunique()
num_ratings = len(ratings)
sparsity = 1 - (num_ratings / (num_users * num_movies))

print(f"Tỷ lệ sparsity của ma trận user-item: {sparsity:.2%}")

# %% [markdown]
# # 🏗️ Bước 3: Chuẩn bị dữ liệu cho mô hình

# %%
# Tạo ma trận user-item (nếu tự code CF)
user_item_matrix = ratings.pivot(index='userId', columns='movieId', values='rating')
user_item_matrix.fillna(0, inplace=True)  # Điền các giá trị NaN bằng 0

print("Kích thước ma trận user-item:", user_item_matrix.shape)
user_item_matrix.head()

# %%
# Chuẩn bị dữ liệu theo format 3 cột (user, item, rating) nếu dùng scikit-surprise
ratings_subset = ratings[['userId', 'movieId', 'rating']]
ratings_subset.head()

# %% [markdown]
# ## ✂️ Bước 4: Chia tập train/test

# %%
from sklearn.model_selection import train_test_split

# Chia dữ liệu theo tỉ lệ 80/20
train, test = train_test_split(ratings, test_size=0.2, random_state=42)

print(f"Số lượng rating trong tập train: {len(train)}")
print(f"Số lượng rating trong tập test: {len(test)}")

# %%
# (Tùy chọn) Chia dữ liệu dựa trên thời gian (Time-based Split)
ratings_sorted = ratings.sort_values(by='timestamp')
split_idx = int(len(ratings_sorted) * 0.8)
train_time_based = ratings_sorted.iloc[:split_idx]
test_time_based = ratings_sorted.iloc[split_idx:]

print(f"Số lượng rating trong tập train (time-based): {len(train_time_based)}")
print(f"Số lượng rating trong tập test (time-based): {len(test_time_based)}")
